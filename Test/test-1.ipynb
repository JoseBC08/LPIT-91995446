# %%
# List example
list = [1, 2, "Pink", 2.23, ['a', 'b', 3], 4]

# %%
print(list)
# Out:
# [1, 2, 'Pink', 2.23, ['a', 'b', 3], 4]

# %%
list
# Out:
# [1, 2, 'Pink', 2.23, ['a', 'b', 3], 4]

# %%
list[0]
# Out:
# 1

# %%
list[-1]
# Out:
# 4

# %%
list[1:4]
# Out:
# [2, 'Pink', 2.23]

# %%
list[-1]
# Out:
# 4

# %%
list.index(2.23)
# Out:
# 3

# %%
# Modify a list element
list[3] = 'Red'

# %%
list
# Out:
# [1, 2, 'Pink', 'Red', ['a', 'b', 3], 4]

# %%
list.append('Hello world!')

# %%
list
# Out:
# [1, 2, 'Pink', 'Red', ['a', 'b', 3], 4, 'Hello world!']

# %%
list.pop()
# Out:
# 'Hello world!'

# %%
list
# Out:
# [1, 2, 'Pink', 'Red', ['a', 'b', 3], 4]

# %%
list.remove('Red')

# %%
list
# Out:
# [1, 2, 'Pink', ['a', 'b', 3], 4]

# %%
list.insert(2, 'Red')

# %%
list
# Out:
# [1, 2, 'Red', 'Pink', ['a', 'b', 3], 4]

# %%
# Tuple example
tuple = (1, 2, 'Pink', 2.23, ['a', 'b', 3], 4)

# %%
tuple[0]
# Out:
# 1

# %%
tuple[-1]
# Out:
# 4

# %%
print(tuple)
# Out:
# (1, 2, 'Pink', 2.23, ['a', 'b', 3], 4)

# %%
# Tuple example
tuple = (1, 2, 3, 'John', ['One', 'Two', 3.14])

# %%
type(tuple)
# Out:
# tuple

# %%
tuple[0]
# Out:
# 1

# %%
tuple[-1]
# Out:
# ['One', 'Two', 3.14]

# %%
print(tuple)
# Out:
# (1, 2, 3, 'John', ['One', 'Two', 3.14])

# %%
tuple[2] = -1  # Tuples are read only
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 tuple[2] = -1  # Tuples are read only
#
# TypeError: 'tuple' object does not support item assignment

# %%
dicc = {1: 'Pink', 2.23: 2, 4: ['a', 'b', 3]}

# %%
type(dicc)
# Out:
# dict

# %%
print(dicc)
# Out:
# {1: 'Pink', 2.23: 2, 4: ['a', 'b', 3]}

# %%
dicc[2.23]
# Out:
# 2

# %%
# Dictionary example
dicc = {'Luna':30, -2.5:'Charlie', 'Ruby':[50, 60,70], 5:{'a':1, 'b':-2, 'c':10}}

# %%
dicc
# Out:
# {'Luna': 30,
#  -2.5: 'Charlie',
#  'Ruby': [50, 60, 70],
#  5: {'a': 1, 'b': -2, 'c': 10}}

# %%
dicc['Luna']
# Out:
# 30

# %%
dicc['Ruby'][2]
# Out:
# 70

# %%
dicc[5]['c']
# Out:
# 10

# %%
# Presence of a key in a diccionary
'Luna' in dicc
# Out:
# True

# %%
'Charlie' in dicc
# Out:
# False

# %%
# List assignment without copy
l2 = list

# %%
list
# Out:
# [1, 2, 'Pink', 'Red', ['a', 'b', 3], 4]

# %%
l2
# Out:
# [1, 2, 'Pink', 'Red', ['a', 'b', 3], 4]

# %%
list[2] = 'Toni'

# %%
list
# Out:
# [1, 2, 'Toni', 'Red', ['a', 'b', 3], 4]

# %%
l2
# Out:
# [1, 2, 'Toni', 'Red', ['a', 'b', 3], 4]

# %%
l2[1] = -3

# %%
list
# Out:
# [1, -3, 'Toni', 'Red', ['a', 'b', 3], 4]

# %%
# List assignment with copy
l3 = list.copy()

# %%
list
# Out:
# [1, -3, 'Toni', 'Red', ['a', 'b', 3], 4]

# %%
l3
# Out:
# [1, -3, 'Toni', 'Red', ['a', 'b', 3], 4]

# %%
list[1] = 0.9

# %%
list
# Out:
# [1, 0.9, 'Toni', 'Red', ['a', 'b', 3], 4]

# %%
l3
# Out:
# [1, -3, 'Toni', 'Red', ['a', 'b', 3], 4]

# %%
list[4]
# Out:
# ['a', 'b', 3]

# %%
list[4][1]='0xB'

# %%
list
# Out:
# [1, 0.9, 'Toni', 'Red', ['a', '0xB', 3], 4]

# %%
l3
# Out:
# [1, -3, 'Toni', 'Red', ['a', '0xB', 3], 4]

# %%
from copy import deepcopy

# %%
# List assignment with deepcopy
l4 = deepcopy(list)

# %%
l4
# Out:
# [1, 0.9, 'Toni', 'Red', ['a', '0xB', 3], 4]

# %%
list[4][1]='0xC'

# %%
list
# Out:
# [1, 0.9, 'Toni', 'Red', ['a', '0xC', 3], 4]

# %%
l4
# Out:
# [1, 0.9, 'Toni', 'Red', ['a', '0xB', 3], 4]
