# %%
import polars as pl

# %%
agg_df = pl.DataFrame({f"v{i}": [] for i in range(10)})

# %%
agg_df
# Out:
# shape: (0, 10)
# ┌──────┬──────┬──────┬──────┬───┬──────┬──────┬──────┬──────┐
# │ v0   ┆ v1   ┆ v2   ┆ v3   ┆ … ┆ v6   ┆ v7   ┆ v8   ┆ v9   │
# │ ---  ┆ ---  ┆ ---  ┆ ---  ┆   ┆ ---  ┆ ---  ┆ ---  ┆ ---  │
# │ null ┆ null ┆ null ┆ null ┆   ┆ null ┆ null ┆ null ┆ null │
# ╞══════╪══════╪══════╪══════╪═══╪══════╪══════╪══════╪══════╡
# └──────┴──────┴──────┴──────┴───┴──────┴──────┴──────┴──────┘
